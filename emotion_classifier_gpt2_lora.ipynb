# %% [markdown]
# <a href="https://colab.research.google.com/github/Brnn043/EmotionClassifierAI/blob/main/emotion_classifier_gpt2_lora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EmotionClassifierAI 😧**
# description

# %%
# !pip install nb-clean

# !nb-clean clean emotion-classifier-gpt2-lora.ipynb
# Out:
# Requirement already satisfied: nb-clean in /usr/local/lib/python3.11/dist-packages (4.0.1)
# Requirement already satisfied: nbformat>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from nb-clean) (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.9.2->nb-clean) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.9.2->nb-clean) (4.24.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.9.2->nb-clean) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.9.2->nb-clean) (5.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=5.9.2->nb-clean) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=5.9.2->nb-clean) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=5.9.2->nb-clean) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=5.9.2->nb-clean) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.9.2->nb-clean) (4.3.8)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat>=5.9.2->nb-clean) (4.14.1)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/nbformat/__init__.py", line 169, in read
#     buf = fp.read()
#           ^^^^^^^
# AttributeError: 'PosixPath' object has no attribute 'read'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/nb-clean", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nb_clean/cli.py", line 319, in main
#     args.func(args)
#   File "/usr/local/lib/python3.11/dist-packages/nb_clean/cli.py", line 153, in clean
#     notebook = nbformat.read(input_, as_version=nbformat.NO_CONVERT)  # type: ignore[no-untyped-call]
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nbformat/__init__.py", line 171, in read
#     with open(fp, encoding="utf8") as f:  # noqa: PTH123
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'emotion-classifier-gpt2-lora.ipynb'

# %% [markdown]
# ## Setup & Install Dependencies

# %%
# !pip install transformers datasets peft evaluate --quiet

# %%
# !pip install numpy==1.24.4
# Out:
# Requirement already satisfied: numpy==1.24.4 in /usr/local/lib/python3.11/dist-packages (1.24.4)

# %% [markdown]
# ## Load Dataset

# %%
from datasets import load_dataset_builder

ds_builder = load_dataset_builder("dair-ai/emotion")

print(ds_builder.info.features)
print(ds_builder.info.splits)
print(ds_builder.info.description)
# Out:
# {'text': Value('string'), 'label': ClassLabel(names=['sadness', 'joy', 'love', 'anger', 'fear', 'surprise'])}
# {'train': SplitInfo(name='train', num_bytes=1743533, num_examples=16000, shard_lengths=None, dataset_name='emotion'), 'validation': SplitInfo(name='validation', num_bytes=214945, num_examples=2000, shard_lengths=None, dataset_name='emotion'), 'test': SplitInfo(name='test', num_bytes=217423, num_examples=2000, shard_lengths=None, dataset_name='emotion')}

# %%
from datasets import load_dataset

dataset = load_dataset("dair-ai/emotion")
# Out:
# train-00000-of-00001.parquet:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/127k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/129k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/16000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
dataset['train']['text'][:10]
# Out:
# ['i didnt feel humiliated',
#  'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake',
#  'im grabbing a minute to post i feel greedy wrong',
#  'i am ever feeling nostalgic about the fireplace i will know that it is still on the property',
#  'i am feeling grouchy',
#  'ive been feeling a little burdened lately wasnt sure why that was',
#  'ive been taking or milligrams or times recommended amount and ive fallen asleep a lot faster but i also feel like so funny',
#  'i feel as confused about life as a teenager or as jaded as a year old man',
#  'i have been with petronas for years i feel that petronas has performed well and made a huge profit',
#  'i feel romantic too']

# %%
label_map = {
    0: "sadness",
    1: "joy",
    2: "love",
    3: "anger",
    4: "fear",
    5: "surprise"
}

string_map = {
    "sadness": 0,
    "joy": 1,
    "love": 2,
    "anger": 3,
    "fear": 4,
    "surprise": 5
}

def label_to_string(label):
    return label_map[label]

def string_to_label(string):
    return string_map[string]

# %% [markdown]
# ## Preprocess Dataset

# %% [markdown]
# ## Loading & Evaluating a Foundation Model

# %% [markdown]
# ## Performing Parameter-Efficient Fine-Tuning (PEFT)
